# %% [markdown]
# <a href="https://colab.research.google.com/github/caveligh/Colab_Projects/blob/main/Seaborn_Matriz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = df = pd.read_csv("/content/drive/MyDrive/Colab/country_table.csv")
df.head()
# Out:
#                          Countries  ...  Growth rate
# 0                           AFRICA  ...        24.40
# 1                             ASIA  ...         8.44
# 2                           EUROPE  ...         0.38
# 3  LATIN AMERICA AND THE CARIBBEAN  ...         8.89
# 4                 NORTHERN AMERICA  ...         6.11
#
# [5 rows x 6 columns]

# %%
df = df.set_index("Countries")

# %%
df
# Out:
#                                  Birth rate  ...  Growth rate
# Countries                                    ...
# AFRICA                               32.577  ...        24.40
# ASIA                                 15.796  ...         8.44
# EUROPE                               10.118  ...         0.38
# LATIN AMERICA AND THE CARIBBEAN      15.886  ...         8.89
# NORTHERN AMERICA                     11.780  ...         6.11
# OCEANIA                              16.235  ...        12.79
# WORLD                                17.963  ...        10.36
#
# [7 rows x 5 columns]

# %%
sns.heatmap(df)

# %%
plt.figure(dpi=200)
sns.heatmap(df.drop("Life expectancy", axis=1), linewidth=0.5, annot=True, cmap="viridis")

# %%
plt.figure(dpi=200)
sns.clustermap(df.drop("Life expectancy", axis=1), linewidth=0.5, annot=True, cmap="viridis")

# %%
plt.figure(dpi=200)
sns.clustermap(df.drop("Life expectancy", axis=1), linewidth=0.5, annot=True, cmap="viridis", col_cluster=False)

# %%
#@markdown Check type of GPU and VRAM available.
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15109 MiB, 15109 MiB

# %% [markdown]
# https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth

# %% [markdown]
# ## Install Requirements

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate==0.12.0 transformers ftfy bitsandbytes gradio natsort
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 182 kB 13.5 MB/s
#   Building wheel for diffusers (PEP 517) ... done
#      |████████████████████████████████| 18.7 MB 15.8 MB/s
#      |████████████████████████████████| 143 kB 14.5 MB/s
#      |████████████████████████████████| 5.8 MB 71.0 MB/s
#      |████████████████████████████████| 53 kB 2.1 MB/s
#      |████████████████████████████████| 62.5 MB 1.2 MB/s
#      |████████████████████████████████| 13.8 MB 58.4 MB/s
#      |████████████████████████████████| 7.6 MB 54.2 MB/s
#      |████████████████████████████████| 106 kB 76.8 MB/s
#      |████████████████████████████████| 55 kB 4.7 MB/s
#      |████████████████████████████████| 278 kB 79.8 MB/s
#      |████████████████████████████████| 56 kB 5.5 MB/s
#      |████████████████████████████████| 2.3 MB 49.5 MB/s
#      |████████████████████████████████| 84 kB 4.2 MB/s
#      |████████████████████████████████| 84 kB 4.7 MB/s
#      |████████████████████████████████| 64 kB 3.2 MB/s
#      |████████████████████████████████| 80 kB 10.7 MB/s
#      |████████████████████████████████| 69 kB 9.1 MB/s
#      |████████████████████████████████| 58 kB 7.7 MB/s
#      |████████████████████████████████| 50 kB 8.6 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %%
#@title Login to HuggingFace 🤗

#@markdown You need to accept the model license before downloading or using the Stable Diffusion weights. Please, visit the [model card](https://huggingface.co/runwayml/stable-diffusion-v1-5), read the license and tick the checkbox if you agree. You have to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work.
# https://huggingface.co/settings/tokens
# !mkdir -p ~/.huggingface
HUGGINGFACE_TOKEN = "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" #@param {type:"string"}
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token

# %% [markdown]
# ### Install xformers from precompiled wheel.

# %%
# %pip install -q https://github.com/brian6091/xformers-wheels/releases/download/0.0.15.dev0%2B4c06c79/xformers-0.0.15.dev0+4c06c79.d20221205-cp38-cp38-linux_x86_64.whl
# These were compiled on Tesla T4.

# If precompiled wheels don't work, install it with the following command. It will take around 40 minutes to compile.
# %pip install git+https://github.com/facebookresearch/xformers@4c06c79#egg=xformers
# Out:
#      |████████████████████████████████| 47.4 MB 1.2 MB/s

# %% [markdown]
# ## Settings and run

# %%
#@markdown If model weights should be saved directly in google drive (takes around 4-5 GB).
save_to_gdrive = False #@param {type:"boolean"}
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')

#@markdown Name/Path of the initial model.
MODEL_NAME = "runwayml/stable-diffusion-v1-5" #@param {type:"string"}

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "stable_diffusion_weights/caveli" #@param {type:"string"}
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "/content/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR
# Out:
# [*] Weights will be saved at /content/stable_diffusion_weights/caveli

# %% [markdown]
# # Start Training
#
# Use the table below to choose the best flags based on your memory and speed requirements. Tested on Tesla T4 GPU.
#
#
# | `fp16` | `train_batch_size` | `gradient_accumulation_steps` | `gradient_checkpointing` | `use_8bit_adam` | GB VRAM usage | Speed (it/s) |
# | ---- | ------------------ | ----------------------------- | ----------------------- | --------------- | ---------- | ------------ |
# | fp16 | 1                  | 1                             | TRUE                    | TRUE            | 9.92       | 0.93         |
# | no   | 1                  | 1                             | TRUE                    | TRUE            | 10.08      | 0.42         |
# | fp16 | 2                  | 1                             | TRUE                    | TRUE            | 10.4       | 0.66         |
# | fp16 | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 1.14         |
# | no   | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 0.49         |
# | fp16 | 1                  | 2                             | TRUE                    | TRUE            | 11.56      | 1            |
# | fp16 | 2                  | 1                             | FALSE                   | TRUE            | 13.67      | 0.82         |
# | fp16 | 1                  | 2                             | FALSE                   | TRUE            | 13.7       | 0.83          |
# | fp16 | 1                  | 1                             | TRUE                    | FALSE           | 15.79      | 0.77         |

# %% [markdown]
# Add `--gradient_checkpointing` flag for around 9.92 GB VRAM usage.
#
# remove `--use_8bit_adam` flag for full precision. Requires 15.79 GB with `--gradient_checkpointing` else 17.8 GB.
#
# remove `--train_text_encoder` flag to reduce memory usage further, degrades output quality.

# %%
# You can also add multiple concepts here. Try tweaking `--max_train_steps` accordingly.

concepts_list = [
    {
        "instance_prompt":      "photo of caveli person",
        "class_prompt":         "photo of a person",
        "instance_data_dir":    "/content/data/caveli person",
        "class_data_dir":       "/content/data/person"
    },
#     {
#         "instance_prompt":      "photo of ukj person",
#         "class_prompt":         "photo of a person",
#         "instance_data_dir":    "/content/data/ukj",
#         "class_data_dir":       "/content/data/person"
#     }
]

# `class_data_dir` contains regularization images
import json
import os
for c in concepts_list:
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)

# %%
#@markdown Upload your images by running this cell.

#@markdown OR

#@markdown You can use the file manager on the left panel to upload (drag and drop) to each `instance_data_dir` (it uploads faster)

import os
from google.colab import files
import shutil

for c in concepts_list:
    print(f"Uploading instance images for `{c['instance_prompt']}`")
    uploaded = files.upload()
    for filename in uploaded.keys():
        dst_path = os.path.join(c['instance_data_dir'], filename)
        shutil.move(filename, dst_path)

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=50 \
  --sample_batch_size=4 \
  --max_train_steps=800 \
  --save_interval=10000 \
  --save_sample_prompt="photo of caveli person" \
  --concepts_list="concepts_list.json"

# Reduce the `--save_interval` to lower than `--max_train_steps` to save weights from intermediate steps.
# `--save_sample_prompt` can be same as `--instance_prompt` to generate intermediate samples (saved along with weights in samples directory).
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--num_cpu_threads_per_process` was set to `1` to improve out-of-box performance
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Downloading: 100% 335M/335M [00:03<00:00, 98.6MB/s]
# Downloading: 100% 547/547 [00:00<00:00, 505kB/s]
# Downloading: 100% 543/543 [00:00<00:00, 512kB/s]
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading: 100% 342/342 [00:00<00:00, 307kB/s]
# Fetching 15 files:   7% 1/15 [00:00<00:10,  1.38it/s]
# Downloading: 100% 4.70k/4.70k [00:00<00:00, 3.84MB/s]
# Fetching 15 files:  20% 3/15 [00:01<00:05,  2.18it/s]
# Downloading:   0% 0.00/608M [00:00<?, ?B/s]
# Downloading:   2% 9.77M/608M [00:00<00:06, 97.7MB/s]
# Downloading:   3% 20.4M/608M [00:00<00:05, 103MB/s]
# Downloading:   5% 31.0M/608M [00:00<00:05, 104MB/s]
# Downloading:   7% 41.9M/608M [00:00<00:05, 106MB/s]
# Downloading:   9% 52.5M/608M [00:00<00:06, 88.6MB/s]
# Downloading:  10% 63.4M/608M [00:00<00:05, 94.6MB/s]
# Downloading:  12% 74.5M/608M [00:00<00:05, 99.5MB/s]
# Downloading:  14% 85.2M/608M [00:00<00:05, 102MB/s]
# Downloading:  16% 95.5M/608M [00:00<00:05, 102MB/s]
# Downloading:  18% 106M/608M [00:01<00:04, 104MB/s]
# Downloading:  19% 117M/608M [00:01<00:05, 90.7MB/s]
# Downloading:  21% 128M/608M [00:01<00:04, 96.4MB/s]
# Downloading:  23% 139M/608M [00:01<00:04, 100MB/s]
# Downloading:  25% 149M/608M [00:01<00:04, 93.5MB/s]
# Downloading:  26% 160M/608M [00:01<00:04, 97.5MB/s]
# Downloading:  28% 171M/608M [00:01<00:04, 101MB/s]
# Downloading:  30% 181M/608M [00:01<00:04, 94.6MB/s]
# Downloading:  32% 193M/608M [00:01<00:04, 99.0MB/s]
# Downloading:  33% 204M/608M [00:02<00:03, 103MB/s]
# Downloading:  35% 214M/608M [00:02<00:04, 98.0MB/s]
# Downloading:  37% 225M/608M [00:02<00:03, 101MB/s]
# Downloading:  39% 236M/608M [00:02<00:03, 105MB/s]
# Downloading:  41% 247M/608M [00:02<00:03, 98.2MB/s]
# Downloading:  42% 257M/608M [00:02<00:03, 96.2MB/s]
# Downloading:  44% 268M/608M [00:02<00:03, 98.6MB/s]
# Downloading:  46% 278M/608M [00:02<00:03, 100MB/s]
# Downloading:  48% 289M/608M [00:02<00:03, 103MB/s]
# Downloading:  49% 300M/608M [00:03<00:02, 106MB/s]
# Downloading:  51% 311M/608M [00:03<00:02, 106MB/s]
# Downloading:  53% 322M/608M [00:03<00:02, 97.5MB/s]
# Downloading:  55% 331M/608M [00:03<00:02, 94.8MB/s]
# Downloading:  56% 342M/608M [00:03<00:02, 96.9MB/s]
# Downloading:  58% 352M/608M [00:03<00:02, 98.6MB/s]
# Downloading:  60% 362M/608M [00:03<00:02, 97.7MB/s]
# Downloading:  61% 373M/608M [00:03<00:02, 101MB/s]
# Downloading:  63% 383M/608M [00:03<00:02, 103MB/s]
# Downloading:  65% 394M/608M [00:03<00:02, 92.5MB/s]
# Downloading:  66% 404M/608M [00:04<00:02, 94.9MB/s]
# Downloading:  68% 414M/608M [00:04<00:02, 96.1MB/s]
# Downloading:  70% 424M/608M [00:04<00:01, 95.6MB/s]
# Downloading:  71% 433M/608M [00:04<00:01, 91.2MB/s]
# Downloading:  73% 443M/608M [00:04<00:01, 94.4MB/s]
# Downloading:  74% 453M/608M [00:04<00:01, 93.0MB/s]
# Downloading:  76% 463M/608M [00:04<00:01, 94.3MB/s]
# Downloading:  78% 473M/608M [00:04<00:01, 97.1MB/s]
# Downloading:  80% 484M/608M [00:04<00:01, 99.6MB/s]
# Downloading:  81% 494M/608M [00:05<00:01, 94.0MB/s]
# Downloading:  83% 503M/608M [00:05<00:01, 88.3MB/s]
# Downloading:  84% 513M/608M [00:05<00:01, 91.4MB/s]
# Downloading:  86% 524M/608M [00:05<00:00, 95.7MB/s]
# Downloading:  88% 533M/608M [00:05<00:00, 95.9MB/s]
# Downloading:  89% 544M/608M [00:05<00:00, 97.5MB/s]
# Downloading:  91% 553M/608M [00:05<00:00, 97.5MB/s]
# Downloading:  93% 564M/608M [00:05<00:00, 99.5MB/s]
# Downloading:  94% 574M/608M [00:05<00:00, 101MB/s]
# Downloading:  96% 585M/608M [00:05<00:00, 102MB/s]
# Downloading:  98% 595M/608M [00:06<00:00, 104MB/s]
# Downloading: 100% 608M/608M [00:06<00:00, 98.3MB/s]
# Fetching 15 files:  27% 4/15 [00:08<00:28,  2.57s/it]
# Downloading: 100% 307/307 [00:00<00:00, 261kB/s]
# Fetching 15 files:  33% 5/15 [00:08<00:19,  1.96s/it]
# Downloading: 100% 636/636 [00:00<00:00, 452kB/s]
# Fetching 15 files:  40% 6/15 [00:09<00:14,  1.57s/it]
# Downloading:   0% 0.00/246M [00:00<?, ?B/s]
# Downloading:   3% 6.24M/246M [00:00<00:03, 62.4MB/s]
# Downloading:   6% 13.6M/246M [00:00<00:03, 69.2MB/s]
# Downloading:  10% 23.4M/246M [00:00<00:02, 82.3MB/s]
# Downloading:  14% 33.5M/246M [00:00<00:02, 89.6MB/s]
# Downloading:  18% 43.2M/246M [00:00<00:02, 92.1MB/s]
# Downloading:  22% 53.3M/246M [00:00<00:02, 95.3MB/s]
# Downloading:  26% 62.8M/246M [00:00<00:01, 95.3MB/s]
# Downloading:  30% 73.3M/246M [00:00<00:01, 98.3MB/s]
# Downloading:  34% 83.1M/246M [00:00<00:01, 92.8MB/s]
# Downloading:  38% 93.4M/246M [00:01<00:01, 95.6MB/s]
# Downloading:  42% 104M/246M [00:01<00:01, 98.7MB/s]
# Downloading:  46% 114M/246M [00:01<00:01, 94.8MB/s]
# Downloading:  51% 124M/246M [00:01<00:01, 97.8MB/s]
# Downloading:  55% 135M/246M [00:01<00:01, 101MB/s]
# Downloading:  59% 145M/246M [00:01<00:01, 98.2MB/s]
# Downloading:  63% 155M/246M [00:01<00:00, 96.4MB/s]
# Downloading:  68% 166M/246M [00:01<00:00, 101MB/s]
# Downloading:  72% 177M/246M [00:01<00:00, 102MB/s]
# Downloading:  76% 187M/246M [00:01<00:00, 97.2MB/s]
# Downloading:  80% 198M/246M [00:02<00:00, 101MB/s]
# Downloading:  85% 209M/246M [00:02<00:00, 102MB/s]
# Downloading:  89% 219M/246M [00:02<00:00, 96.9MB/s]
# Downloading:  93% 230M/246M [00:02<00:00, 100MB/s]
# Downloading: 100% 246M/246M [00:02<00:00, 96.4MB/s]
# Fetching 15 files:  47% 7/15 [00:12<00:16,  2.00s/it]
# Downloading:   0% 0.00/525k [00:00<?, ?B/s]
# Downloading:   8% 41.0k/525k [00:00<00:02, 242kB/s]
# Downloading: 100% 525k/525k [00:00<00:00, 1.23MB/s]
# Fetching 15 files:  53% 8/15 [00:13<00:12,  1.74s/it]
# Downloading: 100% 472/472 [00:00<00:00, 441kB/s]
# Fetching 15 files:  60% 9/15 [00:14<00:08,  1.43s/it]
# Downloading: 100% 822/822 [00:00<00:00, 717kB/s]
# Fetching 15 files:  67% 10/15 [00:15<00:06,  1.22s/it]
# Downloading:   0% 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   3% 36.9k/1.06M [00:00<00:04, 217kB/s]
# Downloading:  17% 180k/1.06M [00:00<00:01, 584kB/s]
# Downloading: 100% 1.06M/1.06M [00:00<00:00, 2.06MB/s]
# Fetching 15 files:  73% 11/15 [00:16<00:04,  1.23s/it]
# Downloading: 100% 806/806 [00:00<00:00, 720kB/s]
# Fetching 15 files:  80% 12/15 [00:17<00:03,  1.08s/it]
# Downloading:   0% 0.00/1.72G [00:00<?, ?B/s]
# Downloading:   1% 8.77M/1.72G [00:00<00:19, 87.7MB/s]
# Downloading:   1% 17.9M/1.72G [00:00<00:18, 90.1MB/s]
# Downloading:   2% 27.0M/1.72G [00:00<00:19, 85.5MB/s]
# Downloading:   2% 37.0M/1.72G [00:00<00:18, 91.2MB/s]
# Downloading:   3% 47.3M/1.72G [00:00<00:17, 95.5MB/s]
# Downloading:   3% 57.0M/1.72G [00:00<00:17, 95.9MB/s]
# Downloading:   4% 67.4M/1.72G [00:00<00:16, 98.6MB/s]
# Downloading:   5% 78.4M/1.72G [00:00<00:16, 102MB/s]
# Downloading:   5% 88.6M/1.72G [00:00<00:17, 95.4MB/s]
# Downloading:   6% 98.9M/1.72G [00:01<00:16, 97.8MB/s]
# Downloading:   6% 109M/1.72G [00:01<00:16, 99.0MB/s]
# Downloading:   7% 119M/1.72G [00:01<00:17, 91.1MB/s]
# Downloading:   7% 129M/1.72G [00:01<00:17, 92.8MB/s]
# Downloading:   8% 139M/1.72G [00:01<00:16, 95.2MB/s]
# Downloading:   9% 148M/1.72G [00:01<00:17, 90.3MB/s]
# Downloading:   9% 159M/1.72G [00:01<00:16, 94.1MB/s]
# Downloading:  10% 169M/1.72G [00:01<00:15, 96.9MB/s]
# Downloading:  10% 179M/1.72G [00:01<00:15, 97.4MB/s]
# Downloading:  11% 189M/1.72G [00:02<00:16, 92.8MB/s]
# Downloading:  12% 199M/1.72G [00:02<00:16, 94.7MB/s]
# Downloading:  12% 208M/1.72G [00:02<00:15, 95.2MB/s]
# Downloading:  13% 218M/1.72G [00:02<00:16, 89.4MB/s]
# Downloading:  13% 228M/1.72G [00:02<00:16, 91.7MB/s]
# Downloading:  14% 238M/1.72G [00:02<00:15, 94.3MB/s]
# Downloading:  14% 248M/1.72G [00:02<00:15, 96.0MB/s]
# Downloading:  15% 258M/1.72G [00:02<00:15, 96.8MB/s]
# Downloading:  16% 268M/1.72G [00:02<00:14, 98.0MB/s]
# Downloading:  16% 278M/1.72G [00:02<00:14, 98.4MB/s]
# Downloading:  17% 288M/1.72G [00:03<00:16, 89.3MB/s]
# Downloading:  17% 298M/1.72G [00:03<00:15, 93.0MB/s]
# Downloading:  18% 307M/1.72G [00:03<00:15, 88.6MB/s]
# Downloading:  18% 318M/1.72G [00:03<00:15, 92.7MB/s]
# Downloading:  19% 329M/1.72G [00:03<00:14, 97.1MB/s]
# Downloading:  20% 339M/1.72G [00:03<00:13, 100MB/s]
# Downloading:  20% 350M/1.72G [00:03<00:13, 102MB/s]
# Downloading:  21% 361M/1.72G [00:03<00:13, 103MB/s]
# Downloading:  22% 371M/1.72G [00:03<00:14, 95.2MB/s]
# Downloading:  22% 381M/1.72G [00:04<00:14, 95.3MB/s]
# Downloading:  23% 390M/1.72G [00:04<00:13, 95.3MB/s]
# Downloading:  23% 400M/1.72G [00:04<00:13, 96.2MB/s]
# Downloading:  24% 410M/1.72G [00:04<00:13, 93.6MB/s]
# Downloading:  24% 421M/1.72G [00:04<00:13, 97.7MB/s]
# Downloading:  25% 431M/1.72G [00:04<00:13, 98.9MB/s]
# Downloading:  26% 441M/1.72G [00:04<00:13, 94.7MB/s]
# Downloading:  26% 452M/1.72G [00:04<00:12, 98.7MB/s]
# Downloading:  27% 462M/1.72G [00:04<00:12, 101MB/s]
# Downloading:  27% 472M/1.72G [00:04<00:13, 95.3MB/s]
# Downloading:  28% 483M/1.72G [00:05<00:12, 97.2MB/s]
# Downloading:  29% 493M/1.72G [00:05<00:12, 99.9MB/s]
# Downloading:  29% 503M/1.72G [00:05<00:13, 92.7MB/s]
# Downloading:  30% 514M/1.72G [00:05<00:12, 96.5MB/s]
# Downloading:  31% 525M/1.72G [00:05<00:11, 100MB/s]
# Downloading:  31% 535M/1.72G [00:05<00:12, 96.1MB/s]
# Downloading:  32% 545M/1.72G [00:05<00:12, 93.6MB/s]
# Downloading:  32% 555M/1.72G [00:05<00:11, 97.2MB/s]
# Downloading:  33% 566M/1.72G [00:05<00:11, 99.1MB/s]
# Downloading:  34% 576M/1.72G [00:06<00:11, 101MB/s]
# Downloading:  34% 586M/1.72G [00:06<00:11, 101MB/s]
# Downloading:  35% 597M/1.72G [00:06<00:11, 94.3MB/s]
# Downloading:  35% 606M/1.72G [00:06<00:11, 93.8MB/s]
# Downloading:  36% 617M/1.72G [00:06<00:11, 97.7MB/s]
# Downloading:  36% 627M/1.72G [00:06<00:11, 99.0MB/s]
# Downloading:  37% 637M/1.72G [00:06<00:11, 98.3MB/s]
# Downloading:  38% 647M/1.72G [00:06<00:10, 99.4MB/s]
# Downloading:  38% 657M/1.72G [00:06<00:11, 89.7MB/s]
# Downloading:  39% 666M/1.72G [00:06<00:12, 87.4MB/s]
# Downloading:  39% 677M/1.72G [00:07<00:11, 91.6MB/s]
# Downloading:  40% 687M/1.72G [00:07<00:11, 93.8MB/s]
# Downloading:  41% 696M/1.72G [00:07<00:10, 95.1MB/s]
# Downloading:  41% 706M/1.72G [00:07<00:10, 95.9MB/s]
# Downloading:  42% 717M/1.72G [00:07<00:10, 99.2MB/s]
# Downloading:  42% 727M/1.72G [00:07<00:10, 98.6MB/s]
# Downloading:  43% 737M/1.72G [00:07<00:10, 91.5MB/s]
# Downloading:  43% 747M/1.72G [00:07<00:10, 95.7MB/s]
# Downloading:  44% 758M/1.72G [00:07<00:09, 98.9MB/s]
# Downloading:  45% 769M/1.72G [00:08<00:09, 101MB/s]
# Downloading:  45% 779M/1.72G [00:08<00:09, 101MB/s]
# Downloading:  46% 790M/1.72G [00:08<00:08, 104MB/s]
# Downloading:  47% 801M/1.72G [00:08<00:08, 105MB/s]
# Downloading:  47% 811M/1.72G [00:08<00:08, 102MB/s]
# Downloading:  48% 821M/1.72G [00:08<00:09, 95.0MB/s]
# Downloading:  48% 831M/1.72G [00:08<00:09, 91.7MB/s]
# Downloading:  49% 842M/1.72G [00:08<00:09, 96.6MB/s]
# Downloading:  50% 853M/1.72G [00:08<00:08, 100MB/s]
# Downloading:  50% 863M/1.72G [00:08<00:08, 96.5MB/s]
# Downloading:  51% 873M/1.72G [00:09<00:08, 95.5MB/s]
# Downloading:  51% 883M/1.72G [00:09<00:08, 96.9MB/s]
# Downloading:  52% 893M/1.72G [00:09<00:08, 98.5MB/s]
# Downloading:  53% 903M/1.72G [00:09<00:08, 97.9MB/s]
# Downloading:  53% 914M/1.72G [00:09<00:07, 102MB/s]
# Downloading:  54% 924M/1.72G [00:09<00:08, 99.3MB/s]
# Downloading:  54% 934M/1.72G [00:09<00:08, 91.9MB/s]
# Downloading:  55% 945M/1.72G [00:09<00:08, 96.0MB/s]
# Downloading:  56% 955M/1.72G [00:09<00:07, 97.4MB/s]
# Downloading:  56% 964M/1.72G [00:10<00:08, 92.2MB/s]
# Downloading:  57% 974M/1.72G [00:10<00:07, 93.4MB/s]
# Downloading:  57% 984M/1.72G [00:10<00:07, 95.6MB/s]
# Downloading:  58% 995M/1.72G [00:10<00:07, 97.6MB/s]
# Downloading:  58% 1.00G/1.72G [00:10<00:07, 97.6MB/s]
# Downloading:  59% 1.02G/1.72G [00:10<00:06, 101MB/s]
# Downloading:  60% 1.03G/1.72G [00:10<00:06, 103MB/s]
# Downloading:  60% 1.04G/1.72G [00:10<00:07, 88.0MB/s]
# Downloading:  61% 1.05G/1.72G [00:10<00:07, 91.5MB/s]
# Downloading:  61% 1.06G/1.72G [00:11<00:07, 93.0MB/s]
# Downloading:  62% 1.07G/1.72G [00:11<00:07, 93.2MB/s]
# Downloading:  63% 1.08G/1.72G [00:11<00:06, 95.3MB/s]
# Downloading:  63% 1.09G/1.72G [00:11<00:06, 96.7MB/s]
# Downloading:  64% 1.10G/1.72G [00:11<00:06, 96.0MB/s]
# Downloading:  64% 1.11G/1.72G [00:11<00:06, 98.1MB/s]
# Downloading:  65% 1.12G/1.72G [00:11<00:05, 101MB/s]
# Downloading:  66% 1.13G/1.72G [00:11<00:05, 102MB/s]
# Downloading:  66% 1.14G/1.72G [00:11<00:05, 103MB/s]
# Downloading:  67% 1.15G/1.72G [00:11<00:05, 98.5MB/s]
# Downloading:  67% 1.16G/1.72G [00:12<00:06, 92.8MB/s]
# Downloading:  68% 1.17G/1.72G [00:12<00:05, 96.4MB/s]
# Downloading:  69% 1.18G/1.72G [00:12<00:05, 98.0MB/s]
# Downloading:  69% 1.19G/1.72G [00:12<00:05, 92.6MB/s]
# Downloading:  70% 1.20G/1.72G [00:12<00:05, 94.7MB/s]
# Downloading:  70% 1.21G/1.72G [00:12<00:05, 98.7MB/s]
# Downloading:  71% 1.22G/1.72G [00:12<00:05, 92.4MB/s]
# Downloading:  72% 1.23G/1.72G [00:12<00:05, 96.3MB/s]
# Downloading:  72% 1.24G/1.72G [00:12<00:04, 97.0MB/s]
# Downloading:  73% 1.25G/1.72G [00:12<00:04, 98.1MB/s]
# Downloading:  73% 1.26G/1.72G [00:13<00:04, 98.3MB/s]
# Downloading:  74% 1.27G/1.72G [00:13<00:04, 98.6MB/s]
# Downloading:  74% 1.28G/1.72G [00:13<00:04, 101MB/s]
# Downloading:  75% 1.29G/1.72G [00:13<00:05, 85.2MB/s]
# Downloading:  76% 1.30G/1.72G [00:13<00:04, 91.4MB/s]
# Downloading:  76% 1.31G/1.72G [00:13<00:04, 96.0MB/s]
# Downloading:  77% 1.32G/1.72G [00:13<00:04, 98.0MB/s]
# Downloading:  77% 1.33G/1.72G [00:13<00:04, 95.6MB/s]
# Downloading:  78% 1.34G/1.72G [00:13<00:03, 96.6MB/s]
# Downloading:  79% 1.35G/1.72G [00:14<00:03, 97.1MB/s]
# Downloading:  79% 1.36G/1.72G [00:14<00:03, 97.3MB/s]
# Downloading:  80% 1.37G/1.72G [00:14<00:03, 97.7MB/s]
# Downloading:  80% 1.38G/1.72G [00:14<00:03, 98.2MB/s]
# Downloading:  81% 1.39G/1.72G [00:14<00:03, 88.4MB/s]
# Downloading:  81% 1.40G/1.72G [00:14<00:03, 87.5MB/s]
# Downloading:  82% 1.41G/1.72G [00:14<00:03, 91.4MB/s]
# Downloading:  83% 1.42G/1.72G [00:14<00:03, 93.9MB/s]
# Downloading:  83% 1.43G/1.72G [00:14<00:03, 95.5MB/s]
# Downloading:  84% 1.44G/1.72G [00:15<00:02, 97.5MB/s]
# Downloading:  84% 1.45G/1.72G [00:15<00:02, 98.0MB/s]
# Downloading:  85% 1.46G/1.72G [00:15<00:02, 92.1MB/s]
# Downloading:  86% 1.47G/1.72G [00:15<00:02, 94.9MB/s]
# Downloading:  86% 1.48G/1.72G [00:15<00:02, 97.4MB/s]
# Downloading:  87% 1.49G/1.72G [00:15<00:02, 92.9MB/s]
# Downloading:  87% 1.50G/1.72G [00:15<00:02, 92.4MB/s]
# Downloading:  88% 1.51G/1.72G [00:15<00:02, 95.4MB/s]
# Downloading:  88% 1.52G/1.72G [00:15<00:02, 96.5MB/s]
# Downloading:  89% 1.53G/1.72G [00:15<00:02, 88.4MB/s]
# Downloading:  90% 1.54G/1.72G [00:16<00:01, 91.5MB/s]
# Downloading:  90% 1.55G/1.72G [00:16<00:01, 93.1MB/s]
# Downloading:  91% 1.56G/1.72G [00:16<00:01, 95.1MB/s]
# Downloading:  91% 1.57G/1.72G [00:16<00:01, 97.9MB/s]
# Downloading:  92% 1.58G/1.72G [00:16<00:01, 97.3MB/s]
# Downloading:  92% 1.59G/1.72G [00:16<00:01, 94.8MB/s]
# Downloading:  93% 1.60G/1.72G [00:16<00:01, 96.1MB/s]
# Downloading:  94% 1.61G/1.72G [00:16<00:01, 96.9MB/s]
# Downloading:  94% 1.62G/1.72G [00:16<00:01, 98.3MB/s]
# Downloading:  95% 1.63G/1.72G [00:16<00:00, 98.0MB/s]
# Downloading:  95% 1.64G/1.72G [00:17<00:00, 97.9MB/s]
# Downloading:  96% 1.65G/1.72G [00:17<00:00, 88.6MB/s]
# Downloading:  96% 1.66G/1.72G [00:17<00:00, 87.2MB/s]
# Downloading:  97% 1.67G/1.72G [00:17<00:00, 89.5MB/s]
# Downloading:  98% 1.68G/1.72G [00:17<00:00, 94.8MB/s]
# Downloading:  98% 1.69G/1.72G [00:17<00:00, 93.2MB/s]
# Downloading:  99% 1.70G/1.72G [00:17<00:00, 95.7MB/s]
# Downloading: 100% 1.72G/1.72G [00:17<00:00, 95.8MB/s]
# Fetching 15 files:  87% 13/15 [00:35<00:12,  6.28s/it]
# Downloading: 100% 609/609 [00:00<00:00, 565kB/s]
# Fetching 15 files:  93% 14/15 [00:36<00:04,  4.61s/it]
# Downloading:   0% 0.00/167M [00:00<?, ?B/s]
# Downloading:   5% 8.03M/167M [00:00<00:01, 80.3MB/s]
# Downloading:  10% 17.2M/167M [00:00<00:01, 86.9MB/s]
# Downloading:  15% 25.9M/167M [00:00<00:01, 86.0MB/s]
# Downloading:  21% 34.5M/167M [00:00<00:01, 79.7MB/s]
# Downloading:  26% 44.2M/167M [00:00<00:01, 85.7MB/s]
# Downloading:  32% 53.3M/167M [00:00<00:01, 87.5MB/s]
# Downloading:  38% 63.9M/167M [00:00<00:01, 93.2MB/s]
# Downloading:  44% 73.9M/167M [00:00<00:00, 95.5MB/s]
# Downloading:  50% 83.5M/167M [00:00<00:00, 95.3MB/s]
# Downloading:  56% 93.5M/167M [00:01<00:00, 96.6MB/s]
# Downloading:  62% 103M/167M [00:01<00:00, 97.5MB/s]
# Downloading:  68% 113M/167M [00:01<00:00, 97.3MB/s]
# Downloading:  74% 123M/167M [00:01<00:00, 98.5MB/s]
# Downloading:  80% 133M/167M [00:01<00:00, 88.9MB/s]
# Downloading:  86% 143M/167M [00:01<00:00, 92.5MB/s]
# Downloading:  92% 154M/167M [00:01<00:00, 95.3MB/s]
# Downloading: 100% 167M/167M [00:01<00:00, 93.8MB/s]
# Fetching 15 files: 100% 15/15 [00:38<00:00,  2.55s/it]
# Generating class images: 100% 13/13 [07:00<00:00, 32.38s/it]
# Downloading: 100% 1.06M/1.06M [00:00<00:00, 2.45MB/s]
# Downloading: 100% 525k/525k [00:00<00:00, 1.22MB/s]
# Downloading: 100% 472/472 [00:00<00:00, 441kB/s]
# Downloading: 100% 822/822 [00:00<00:00, 774kB/s]
# Downloading: 100% 636/636 [00:00<00:00, 612kB/s]
# Downloading: 100% 246M/246M [00:02<00:00, 94.8MB/s]
# /usr/local/lib/python3.8/dist-packages/diffusers/utils/deprecation_utils.py:35: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   warnings.warn(warning + message, FutureWarning)
# Downloading: 100% 308/308 [00:00<00:00, 261kB/s]
# Caching latents: 100% 50/50 [00:10<00:00,  4.57it/s]
# Steps: 100% 800/800 [11:37<00:00,  1.16it/s, loss=0.26, lr=1e-6]
# Fetching 15 files: 100% 15/15 [00:00<00:00, 17539.60it/s]
# /usr/local/lib/python3.8/dist-packages/diffusers/utils/deprecation_utils.py:35: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.9.0",
#   "beta_end": 0.012,
#   "beta_schedule": "scaled_linear",
#   "beta_start": 0.00085,
#   "clip_sample": false,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "set_alpha_to_one": false,
#   "steps_offset": 0,
#   "trained_betas": null
# }
#  is outdated. `steps_offset` should be set to 1 instead of 0. Please make sure to update the config accordingly as leaving `steps_offset` might led to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   warnings.warn(warning + message, FutureWarning)
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:12<00:36, 12.21s/it]
# Generating samples:  50% 2/4 [00:20<00:20, 10.17s/it]
# Generating samples:  75% 3/4 [00:29<00:09,  9.59s/it]
# Generating samples: 100% 4/4 [00:38<00:00,  9.70s/it]
# [*] Weights saved at /content/stable_diffusion_weights/caveli/800
# Steps: 100% 800/800 [12:36<00:00,  1.06it/s, loss=0.26, lr=1e-6]

# %%
#@markdown Specify the weights directory to use (leave blank for latest)
WEIGHTS_DIR = "" #@param {type:"string"}
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")
# Out:
# [*] WEIGHTS_DIR=/content/stable_diffusion_weights/caveli/800

# %%
#@markdown Run to generate a grid of preview images from the last saved weights.
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

weights_folder = OUTPUT_DIR
folders = sorted([f for f in os.listdir(weights_folder) if f != "0"], key=lambda x: int(x))

row = len(folders)
col = len(os.listdir(os.path.join(weights_folder, folders[0], "samples")))
scale = 4
fig, axes = plt.subplots(row, col, figsize=(col*scale, row*scale), gridspec_kw={'hspace': 0, 'wspace': 0})

for i, folder in enumerate(folders):
    folder_path = os.path.join(weights_folder, folder)
    image_folder = os.path.join(folder_path, "samples")
    images = [f for f in os.listdir(image_folder)]
    for j, image in enumerate(images):
        if row == 1:
            currAxes = axes[j]
        else:
            currAxes = axes[i, j]
        if i == 0:
            currAxes.set_title(f"Image {j}")
        if j == 0:
            currAxes.text(-0.1, 0.5, folder, rotation=0, va='center', ha='center', transform=currAxes.transAxes)
        image_path = os.path.join(image_folder, image)
        img = mpimg.imread(image_path)
        currAxes.imshow(img, cmap='gray')
        currAxes.axis('off')
        
plt.tight_layout()
plt.savefig('grid.png', dpi=72)

# %% [markdown]
# ## Convert weights to ckpt to use in web UIs like AUTOMATIC1111.

# %%
#@markdown Run conversion.
ckpt_path = WEIGHTS_DIR + "/model.ckpt"

half_arg = ""
#@markdown  Whether to convert to fp16, takes half the space (2GB).
fp16 = True #@param {type: "boolean"}
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $WEIGHTS_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# [*] Converted ckpt saved at /content/stable_diffusion_weights/caveli/800/model.ckpt

# %% [markdown]
# ## Inference

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

scheduler = DDIMScheduler(beta_start=0.00085, beta_end=0.012, beta_schedule="scaled_linear", clip_sample=False, set_alpha_to_one=False)
pipe = StableDiffusionPipeline.from_pretrained(model_path, scheduler=scheduler, safety_checker=None, torch_dtype=torch.float16).to("cuda")

g_cuda = None
# Out:
# /usr/local/lib/python3.8/dist-packages/diffusers/utils/deprecation_utils.py:35: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.9.0",
#   "beta_end": 0.012,
#   "beta_schedule": "scaled_linear",
#   "beta_start": 0.00085,
#   "clip_sample": false,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "set_alpha_to_one": false,
#   "steps_offset": 0,
#   "trained_betas": null
# }
#  is outdated. `steps_offset` should be set to 1 instead of 0. Please make sure to update the config accordingly as leaving `steps_offset` might led to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   warnings.warn(warning + message, FutureWarning)

# %%
#@markdown Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = -1 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = "photo of caveli person Watercolor Oil Painting IA Caveli in a bucket" #@param {type:"string"}
negative_prompt = "ugly, fat, hat" #@param {type:"string"}
num_samples = 1 #@param {type:"number"}
guidance_scale = 7.5 #@param {type:"number"}
num_inference_steps = 50 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8D48F7EF10>

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, negative_prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
                prompt, height=int(height), width=int(width),
                negative_prompt=negative_prompt,
                num_images_per_prompt=int(num_samples),
                num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
                generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of zwx dog in a bucket")
            negative_prompt = gr.Textbox(label="Negative Prompt", value="")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=50)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, negative_prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)

# %%
#@title (Optional) Delete diffuser and old weights and only keep the ckpt to free up drive space.

#@markdown [ ! ] Caution, Only execute if you are sure u want to delete the diffuser format weights and only use the ckpt.
import shutil
from glob import glob
import os
for f in glob(OUTPUT_DIR+os.sep+"*"):
    if f != WEIGHTS_DIR:
        shutil.rmtree(f)
        print("Deleted", f)
for f in glob(WEIGHTS_DIR+"/*"):
    if not f.endswith(".ckpt") or not f.endswith(".json"):
        try:
            shutil.rmtree(f)
        except NotADirectoryError:
            continue
        print("Deleted", f)

# %%
#@title Free runtime memory
exit()
